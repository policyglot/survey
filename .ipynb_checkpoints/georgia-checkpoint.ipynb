# %% [markdown]
# # Deriving English Version of Georgian Dataset

# %%
import pandas as pd
import numpy as np
import re
from googletrans import Translator
translator = Translator()

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
filename = 'georgia_unicode.txt'

# %%
def translate_to_eng(txt, src_lang='ka'):
    """
    takes in text in a non-english language, in this case Kartvelian- Georgian
    returns the english translation
    """
    
    try:
        result = translator.translate(txt,
                     src=src_lang, dest="en")
    #In case the organization's language label doesn't match the question language
    except:
        result = translator.translate(txt, dest="en")
        
    return result.text

# %%
translate_to_eng('რამდენი წლის ხართ?')
# Out:
# 'how old are you?'

# %%
data = pd.read_csv(filename, sep="\t", encoding='utf-16', 
                   skip_blank_lines=True,
                   header=0,
                   #skiprows=[0,1],
                   nrows=261)
#I choose 263 lines since the rows after this are generated variables. They would cause trouble with regex

# %%
data.head()
# Out:
#   varname                           varlabel
# 2     _v1            Q1.1 რამდენი წლის ხართ?
# 3     _v2            Q1.1 რამდენი წლის ხართ?
# 4     _v3                 Q1.2 სქესი/გენდერი
# 5     _v4   Q1.3 ამჟამად რა ურთიერთობაში იმყ
# 6     _v5  Q1.4 გქონიათ თუ არა რაიმე რომანტ�

# %%
data.tail()
# Out:
#     varname                            varlabel
# 256   _v255  Q10.16 დაგისვამთ თუ არა კითხვა საჯ
# 257   _v256  Q10.17 გიმუშავიათ ადგ. ორგანიზაცი�
# 258   _v257  Q10.18 გაგიკეთებიათ თუ არა რაიმე შ
# 259   _v258  Q10.19 მოგიწერიათ თუ არა ხელი რაიმ
# 260   _v259  Q10.20 გამოგიხატავთ თქვენი აზრი/ჩ�

# %%
data.drop(labels=[0,1], axis=0, inplace=True)

# %% [markdown]
# The pattern in the data above is Q<number>DOT<variable number of digits>

# %%
#Now we check for matching regex
#This is a regex for Q, followed by any numbers of periods ending with a space bar
test_match = "Q11.1 მე დაგისვით ზოგი ადვილი და ზ"
alphanum_re = r'^Q\d+'

print(re.findall(alphanum_re, test_match))
#The output of the split needs to be saved- the first section links to questions
# Out:
# ['Q11']

# %%
space_re = r'\s+'
re.split(space_re, test_match, maxsplit=1)
# Out:
# ['Q11.1', 'მე დაგისვით ზოგი ადვილი და ზ']

# %%
data[['q_no','question_georgian']] = data.varlabel.str.split(n=1, expand=True)

# %%
data['question_eng'] = data['question_georgian'].progress_apply(translate_to_eng)
# Out:
#   0%|▎                                                                                | 1/263 [00:00<00:00, 979.29it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-0fe87a303139> in translate_to_eng(txt, src_lang)
#       8         result = translator.translate(txt,
# ----> 9                      src=src_lang, dest="en")
#      10     #In case the organization's language label doesn't match the question language
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in translate(self, text, dest, src, **kwargs)
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src, override)
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in do(self, text)
#     194         self._update()
# --> 195         tk = self.acquire(text)
#     196         return tk
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in acquire(self, text)
#     139         # Convert text to ints
# --> 140         for i in text:
#     141             val = ord(i)
#
# TypeError: 'NoneType' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-35cfebe6dff2> in <module>()
# ----> 1 data['question_eng'] = data['question_georgian'].progress_apply(translate_to_eng)
#
# ~\AppData\Roaming\Python\Python36\site-packages\tqdm\std.py in inner(df, func, *args, **kwargs)
#     765                 # on the df using our wrapper (which provides bar updating)
#     766                 try:
# --> 767                     return getattr(df, df_function)(wrapper, **kwargs)
#     768                 finally:
#     769                     t.close()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Roaming\Python\Python36\site-packages\tqdm\std.py in wrapper(*args, **kwargs)
#     760                     # take a fast or slow code path; so stop when t.total==t.n
#     761                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 762                     return func(*args, **kwargs)
#     763
#     764                 # Apply the provided function (in **kwargs)
#
# <ipython-input-4-0fe87a303139> in translate_to_eng(txt, src_lang)
#      10     #In case the organization's language label doesn't match the question language
#      11     except:
# ---> 12         result = translator.translate(txt, dest="en")
#      13
#      14     return result.text
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src, override)
#      76
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
#      80                                     token=token, override=override)
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in do(self, text)
#     193     def do(self, text):
#     194         self._update()
# --> 195         tk = self.acquire(text)
#     196         return tk
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in acquire(self, text)
#     138         a = []
#     139         # Convert text to ints
# --> 140         for i in text:
#     141             val = ord(i)
#     142             if val < 0x10000:
#
# TypeError: 'NoneType' object is not iterable

# %%
# Now we get the original dataset
data
# Out:
#     varname                              varlabel    q_no  \
# 0        NN                                    NN      NN
# 1        ID                                    ID      ID
# 2       _v1               Q1.1 რამდენი წლის ხართ?    Q1.1
# 3       _v2               Q1.1 რამდენი წლის ხართ?    Q1.1
# 4       _v3                    Q1.2 სქესი/გენდერი    Q1.2
# 5       _v4      Q1.3 ამჟამად რა ურთიერთობაში იმყ    Q1.3
# 6       _v5     Q1.4 გქონიათ თუ არა რაიმე რომანტ�    Q1.4
# 7       _v6      Q1.5 ოდესმე გიცხოვრიათ პარტნიორ�    Q1.5
# 8       _v7      Q1.6 დაასახელეთ თქვენი განათლებ�    Q1.6
# 9       _v8      Q1.7 რომელ ეთნიკური ჯგუფს მიეკუთ    Q1.7
# 10      _v9      Q1.7 რომელ ეთნიკური ჯგუფს მიეკუთ    Q1.7
# 11     _v10          Q1.8 რომელია თქვენი რელიგია?    Q1.8
# 12     _v11     Q1.9 თქვენს გარდა ცხოვრობს თუ არ�    Q1.9
# 13     _v12    Q1.9.1 თქვენს გარდა რამდენი ადამი�  Q1.9.1
# 14     _v13    Q1.10. ვინ ცხოვრობს თქვენთან ერთა�  Q1.10.
# 15     _v14    Q1.10. ვინ ცხოვრობს თქვენთან ერთა�  Q1.10.
# 16     _v15    Q1.10. ვინ ცხოვრობს თქვენთან ერთა�  Q1.10.
# 17     _v16    Q1.10. ვინ ცხოვრობს თქვენთან ერთა�  Q1.10.
# 18     _v17    Q1.10. ვინ ცხოვრობს თქვენთან ერთა�  Q1.10.
# 19     _v18      Q1.11 ვინ უზრუნველყოფს შემოსავლი   Q1.11
# 20     _v19      Q1.11 ვინ უზრუნველყოფს შემოსავლი   Q1.11
# 21     _v20    Q1.12 რამდენია თქვენი (პირადი) ყოვ   Q1.12
# 22     _v21     Q1.13 თქვენი ოჯახის ამჟამინდელ მ�   Q1.13
# 23     _v22     Q1.14 როგორია თქვენი დასაქმების �   Q1.14
# 24     _v23         Q1.15 რომელ სექტორში მუშაობთ?   Q1.15
# 25     _v24         Q1.15 რომელ სექტორში მუშაობთ?   Q1.15
# 26     _v25     Q1.16 კმაყოფილი ვარ ჩემი ახლანდე�   Q1.16
# 27     _v26     Q1.17 ჩემი ახლანდელი ხელფასი შეე�   Q1.17
# 28     _v27    Q1.18 ჩემი ოჯახი ხელს მიწყობს კარ�   Q1.18
# 29     _v28    Q1.19 ჩემი მეუღლე ხელს მიწყობს კა�   Q1.19
# ..      ...                                   ...     ...
# 233   _v232     Q9.24 ბავშვთან თამაში ან სხვადას�   Q9.24
# 234   _v233     Q9.25 ბავშვისთვის გაბრაზება (ვერ�   Q9.25
# 235   _v234         Q9.26 ბავშვის გატყეპა ან ცემა   Q9.26
# 236   _v235     Q9.27 ბავშვის საფენის ან ტანსაცმ�   Q9.27
# 237   _v236                 Q9.28 ბავშვის ბანაობა   Q9.28
# 238   _v237     Q9.29 ბავშვთან პირად საკითხებზე �   Q9.29
# 239   _v238      Q9.30 ბავშვისთვის საშინაო დავალე   Q9.30
# 240   _v239    Q9.31 თქვენი აზრით, ზოგადად მისაღ�   Q9.31
# 241   _v240    Q10.1 არსებობს თუ არა კანონი, მამე   Q10.1
# 242   _v241    Q10.2 აუცილებელია თუ არა კანონი, მ   Q10.2
# 243   _v242     Q10.3 არსებობს თუ არა საქართველო�   Q10.3
# 244   _v243     Q10.4 არსებობს თუ არა საქართველო�   Q10.4
# 245   _v244    Q10.5 ჩადის თუ არა სისხ.სამართ.დან   Q10.5
# 246   _v245   Q10.6 უჭერთ თუ არა მხარს კვოტებს, �   Q10.6
# 247   _v246   Q10.7 უჭერთ თუ არა მხარს კანონს, მ�   Q10.7
# 248   _v247    Q10.8 თქვენი აზრით, რას ნიშნავს/რა   Q10.8
# 249   _v248                 Q10.9 მშობლების სახლი   Q10.9
# 250   _v249                           Q10.10 მიწა  Q10.10
# 251   _v250                  Q10.11 ძვირფასეულობა  Q10.11
# 252   _v251  Q10.12 ფული, მანქანა, სხვა მოძრავი �  Q10.12
# 253   _v252                 Q10.13 ოჯახის ბიზნესი  Q10.13
# 254   _v253    Q10.14 დასწრებიხართ თუ არა ოდესმე   Q10.14
# 255   _v254    Q10.15 მიგიმართავთ თუ არა საჯაროდ   Q10.15
# 256   _v255    Q10.16 დაგისვამთ თუ არა კითხვა საჯ  Q10.16
# 257   _v256    Q10.17 გიმუშავიათ ადგ. ორგანიზაცი�  Q10.17
# 258   _v257    Q10.18 გაგიკეთებიათ თუ არა რაიმე შ  Q10.18
# 259   _v258    Q10.19 მოგიწერიათ თუ არა ხელი რაიმ  Q10.19
# 260   _v259    Q10.20 გამოგიხატავთ თქვენი აზრი/ჩ�  Q10.20
# 261   _v260    Q11.1 მე დაგისვით ზოგი ადვილი და ზ   Q11.1
# 262   _v261    Q11.2 ხომ არა გაქვთ რაიმე შენიშვნ�   Q11.2
#
#                  question_georgian
# 0                             None
# 1                             None
# 2               რამდენი წლის ხართ?
# 3               რამდენი წლის ხართ?
# 4                    სქესი/გენდერი
# 5      ამჟამად რა ურთიერთობაში იმყ
# 6     გქონიათ თუ არა რაიმე რომანტ�
# 7      ოდესმე გიცხოვრიათ პარტნიორ�
# 8      დაასახელეთ თქვენი განათლებ�
# 9      რომელ ეთნიკური ჯგუფს მიეკუთ
# 10     რომელ ეთნიკური ჯგუფს მიეკუთ
# 11         რომელია თქვენი რელიგია?
# 12    თქვენს გარდა ცხოვრობს თუ არ�
# 13     თქვენს გარდა რამდენი ადამი�
# 14     ვინ ცხოვრობს თქვენთან ერთა�
# 15     ვინ ცხოვრობს თქვენთან ერთა�
# 16     ვინ ცხოვრობს თქვენთან ერთა�
# 17     ვინ ცხოვრობს თქვენთან ერთა�
# 18     ვინ ცხოვრობს თქვენთან ერთა�
# 19      ვინ უზრუნველყოფს შემოსავლი
# 20      ვინ უზრუნველყოფს შემოსავლი
# 21    რამდენია თქვენი (პირადი) ყოვ
# 22     თქვენი ოჯახის ამჟამინდელ მ�
# 23     როგორია თქვენი დასაქმების �
# 24         რომელ სექტორში მუშაობთ?
# 25         რომელ სექტორში მუშაობთ?
# 26     კმაყოფილი ვარ ჩემი ახლანდე�
# 27     ჩემი ახლანდელი ხელფასი შეე�
# 28    ჩემი ოჯახი ხელს მიწყობს კარ�
# 29    ჩემი მეუღლე ხელს მიწყობს კა�
# ..                             ...
# 233    ბავშვთან თამაში ან სხვადას�
# 234    ბავშვისთვის გაბრაზება (ვერ�
# 235        ბავშვის გატყეპა ან ცემა
# 236    ბავშვის საფენის ან ტანსაცმ�
# 237                ბავშვის ბანაობა
# 238    ბავშვთან პირად საკითხებზე �
# 239     ბავშვისთვის საშინაო დავალე
# 240   თქვენი აზრით, ზოგადად მისაღ�
# 241   არსებობს თუ არა კანონი, მამე
# 242   აუცილებელია თუ არა კანონი, მ
# 243    არსებობს თუ არა საქართველო�
# 244    არსებობს თუ არა საქართველო�
# 245   ჩადის თუ არა სისხ.სამართ.დან
# 246  უჭერთ თუ არა მხარს კვოტებს, �
# 247  უჭერთ თუ არა მხარს კანონს, მ�
# 248   თქვენი აზრით, რას ნიშნავს/რა
# 249                მშობლების სახლი
# 250                           მიწა
# 251                  ძვირფასეულობა
# 252  ფული, მანქანა, სხვა მოძრავი �
# 253                 ოჯახის ბიზნესი
# 254    დასწრებიხართ თუ არა ოდესმე
# 255    მიგიმართავთ თუ არა საჯაროდ
# 256    დაგისვამთ თუ არა კითხვა საჯ
# 257    გიმუშავიათ ადგ. ორგანიზაცი�
# 258    გაგიკეთებიათ თუ არა რაიმე შ
# 259    მოგიწერიათ თუ არა ხელი რაიმ
# 260    გამოგიხატავთ თქვენი აზრი/ჩ�
# 261   მე დაგისვით ზოგი ადვილი და ზ
# 262   ხომ არა გაქვთ რაიმე შენიშვნ�
#
# [263 rows x 4 columns]

# %%
#Now we derive the unique values (the labels for each category and translate them

#Finally, we store these unique values in the original label-match dataframe.
